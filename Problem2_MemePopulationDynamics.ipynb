# %% [markdown]
# # CS249 -- Take-Home Midterm -- Spring 2014

# %% [markdown]
# ##This problem is to be answered by your project team, working together.
#
# Please have <i>one</i> team member submit your final Notebook on CourseWeb.
# Make sure all team members' names are included below.

# %%
# %load_ext rmagic
import rpy2 as Rpy

# %% [markdown]
# ##Team Members
#
# <ul><li>
# <b>Brian Liu</b> (brianliu@cs.ucla.edu)
# </li><li>
# <b>Stanley Ku</b> (stanleyku@ucla.edu)
# </li></ul>

# %% [markdown]
# # Problem 2: Meme Population Dynamics

# %% [markdown]
# ##The Idea
#
# Please look at <b>NameVoyager</b>, at the site http://www.babynamewizard.com/voyager
# -- and enter the first few letters names in the input box there.
#
# NameVoyager has been very popular, and has gotten recognition for its interesting "visualization" interface.
#
# As the letters you type get closer to the end of a name, the number of names with the same prefix decreases,
# and eventually we see only the history of numbers of occurrences of one name.
#
# The result is often -- interestingly -- a curve like the one below.  It does not always look exactly like this,
# and sometimes doesn't "die" like this one, but many if not most curves look like this:

# %%
# %%R
# library(MASS)

# %%
# %%R
#
# dpareto=function(x, shape=1, location=1) shape * location^shape / x^(shape + 1);
# ppareto=function(x, shape=1, location=1) (x >= location) * (1 - (location / x)^shape);
# qpareto=function(u, shape=1, location=1) location/(1 - u)^(1 / shape);
# rpareto=function(n, shape=1, location=1) qpareto(runif(n), shape, location);
# plot(function(x) {dpareto(x, shape = 1)}, 1, 3, ylab="power law density")
# plot(function(x) {dpareto(x, shape = 1.5)}, 1, 3, col="red", add=TRUE)
# plot(function(x) {dpareto(x, shape = 2)}, 1, 3, col="blue", add=TRUE)
# plot(function(x) {dpareto(x, shape = .33)}, 1, 3, col="blue", add=TRUE)
# legend(x = "topright", legend = c("alpha = 1", "alpha = 1.5", "alpha = 2"),  lty = c(1, 1, 1), col = c("black", "red", "blue"))

# %%
# %%R
#
# # Function to determine location parameter of pareto dist using MLE estimate from data
# location = function(d, max=100)  {
#     stat = NULL;
#     p = NULL;
#     mstat = 1;
#     mp = NULL;
#     mlocation = NULL;
#     mshape = NULL;
#     for (location in 1:max) {
#         d = d[d >= location];
#         # MLE for shape parameter (discrete case)
#         shape = 1 / mean(log(d / (location - 0.5)));
#         t = ks.test(d, "ppareto", shape = shape, location = location);
#         stat[location] = t$stat;
#         p[location] = t$p;
#         if (stat[location] < mstat) {
#              mstat = stat[location];
#              mp = p[location];
#              mlocation = location;
#              mshape = shape;
#         }
#     }
#     return(list(stat=mstat, p=mp, shape=mshape, location=mlocation, statvec=stat, pvec=p));
# }

# %%
# %%R
# fit_comparisions1 = function(data) {
#     # function which returns an int which represents a probability distribution (lognormal, exp, or pareto)
#     # which has the highest p-value after running the KS test on it.
#     meanlog = mean(log(data));
#     sdlog = sd(log(data));
#     par = location(data, 100);
#     shape = par$shape;
#     location = par$location;
#     exp <-fitdistr(data,"exponential")
#         pareto_test = ks.test(data[data>=location], "ppareto", shape = shape, location = location);
#     lognormal_test = ks.test(data, "plnorm", meanlog = meanlog, sdlog = sdlog);
#     exp_test = ks.test(data, "pexp", exp$estimate);
#
#    # cat("lognormal fit p-value: ");print(lognormal_test$p.value)
#    # cat("exp fit p-value: ");print (exp_test$p.value)
#    # cat("Pareto fit ksp p-value:");print(pareto_test$p.value);
#       maxpvalue = max(lognormal_test$p.value, exp_test$p.value, pareto_test$p.value)
#     print(maxpvalue)
#     if (maxpvalue == lognormal_test$p.value)
#         {
#         cat("lognormal has the highest ks test p-value: ");print(lognormal_test$p.value)
#         return(c(1,lognormal_test$p.value))
#         }
#     else if (maxpvalue==exp_test$p.value)
#         {
#         cat("exp has the highest ks test p-value: ");print(exp_test$p.value)
#         return(c(2,exp_test$p.value))
#         }
#     else
#         {
#         cat("pareto has the highest ks test p-value: ");print(pareto_test$p.value)
#         return(c(3,pareto_test$p.value))
#         }
#
#
# }
# Jerry_count = c(25,59,149,392,781,1121,1679,2053,2654,2524,1709,1190,849,583,509,330,241,189,120,76,38,18,8)
# a=fit_comparisions1(Jerry_count)
# Out:
# [1] 0.9234546
# lognormal has the highest ks test p-value: [1] 0.9234546

# %%
# %%R -h 500 -w 600
# years = seq(1900,2010,by=5)
# Jerry_count = c(25,59,149,392,781,1121,1679,2053,2654,2524,1709,1190,849,583,509,330,241,189,120,76,38,18,8)
# print(fit_comparisions1(Jerry_count))
#
# # Our ks test comparing log-normal vs exponential vs pareto p values suggests that a pareto distribution is
# # a better fit. A high p-value means that the model is a poor fit so we choose the model with
# # the lowest ks test p-value as the appropriate model for any particular name.  However, the log-normal
# # p-value is much higher suggesting it is the better model for this particular subset of the data;
# # however we have very few data points to work with so the power of us choosing this model is not
# # particularly strong.
#
# plot(years, Jerry_count, type="n", main="Typical curve showing number of occurrences of a name",
#     sub="This is for 'Jerry', but the curve shape is extremely common among all names", cex.sub=1.25, cex.main=1.6)
# polygon( c(1880, years, 2010, 1880), c(0, Jerry_count, 0,0), col="deepskyblue", border="lightgray" )
# Out:
# [1] 0.9234546
# lognormal has the highest ks test p-value: [1] 0.9234546
# [1] 1.0000000 0.9234546

# %% [markdown]
# ##Population Dynamics:  Competition in a World of Memes
#
# The life-cycle curves in news articles track the <b>population size</b> of the articles.
# At first the population shoots up, then levels off, and starts to drop steeply.
# Other news memes fight for attention, and older memes lose their staying power.
# Eventually all instances of the older meme can disappear.
#
# You have heard of "Predator-Prey models'.
# The field of Population Dynamics (http://en.wikipedia.org/wiki/Population_dynamics) develops mathematical models of processes like this.  The curve above resembles that of a prey that initially multiplies rapidly but is then overcome by predators.
# A popular mathematical formulation using differential equations is known as the Lotka-Volterra equation
# (http://en.wikipedia.org/wiki/Lotka%E2%80%93Volterra_equation).
# Predator-prey models measure the effect of resources (like food, or in new cycles, like attention of readers) on population sizes.
# Limited resources cause competition, which can then lead to large increases and decreases in population size.
#
# The point here is that the curve shape above might somehow be modeled by a curve that arises in population dynamics,
# and there might actually be a justifiable mathematical model for these curves.
# This is the point of departure for this problem:  is there a model for the life-cycle of baby names?
#
# ##Convince yourself
#
# Perhaps the best way to start thinking about this problem is to try out http://www.babynamewizard.com/voyager on many names,
# and study the shapes of curves you find.  (Does the same curve really arise that often?
# Does it arise no matter how many instances of the name there are? etc.)
# Once you have a good sense of what you can actually find in the data, you are ready to go.

# %% [markdown]
# #The Problem:  <u>analyze Meme Life-Cycle (Population Size) curves in a Large Dataset</u>
#
# First, <b>select a time series dataset that is interesting.</b>
# For example, you can select any one of these:
# <ul><li>
# <b>The SSA Baby Names dataset</b>
# </li><li>
# <b>Google Trends</b>
# </li><li>
# An n-grams dataset, like <b>Google N-Grams</b> or <b>Microsoft N-Grams</b>
# </li></ul>
# Essentially you can select any large dataset that has "Meme Life-Cycle" patterns.
# It can be your course project dataset if you prefer that to Baby Names.
# <br/><br/>
#
# Once you have selected your dataset, the problem you are to answer is this:
# <blockquote><i><b>
# <b>Essence of the Problem</b>
# <br/><br/>
# The key question you want to answer here is whether the "meme life-cycle" pattern is "scale-invariant" somehow
# There are instances of the curve for names with lots of occurrences (like "Jerry" above),
# and instances of the curve with few occurrences (like "Jermaine").
# Does this life-cycle shape occur in the same way for <i>all</i> names,
# independent of how many occurrences of the name there are?
# (http://en.wikipedia.org/wiki/Scale_invariance)
# <br/><br/>
# In other words, although the number of occurrences of names vary a lot (i.e., the scales of names can vary),
# the curves seem to have the same shape.
# Also, most curves seem to have this shape, no matter what scale we consider.
# Is this true?
# <br/><br/>
# If so, it suggests some kind of "scale invariance" property of a power law
# (http://en.wikipedia.org/wiki/Power_law#Scale_invariance).
# </b></i></blockquote>
#
# <br/><br/>
# Specifically, assuming you have selected the Baby Names dataset, the problem is as follows:
# <ol><li>
# Download the actual data (see below).
# </li><li>
# (If it helps you, you can any information you can find on the web, such as the analyses of the Baby Names data in the <i>Python for Data Analysis</i> text included below.)
# </li><li>
# For each name in the dataset, compute its history of occurrences (during 1880-2012).
# </li><li>
# Develop a mathematical model for life-cycle curves that describes the instances you can find in the data.
# </li><li>
# Also develop some measure of "goodness of fit", or "loss function" (as in the texts),
# that you can use to find names for which the data matches your model.
# </li><li>
# Train and test your model in a supervised way -- e.g., on a "gold standard" dataset you develop,
# which could be a set of histories that clearly do or clearly don't look like the meme life-cycle curve.
# </li><li>
# Find all matches of the model in the testing part of the data.
# </li><li>
# Answer these questions:
# <ol><li>
# How many matches does your model find in the data?  (Generate a report with summary statistics.)
# </li><li>
# What is the relationship between total number of occurrences of a name and number of years in its lifetime?  (Plot it.)
# </li><li>
# Sort all matches by their size (number of occurrences of the name), and:
# <ul><li>
# Rank the matches (order all matching names by number of occurrences, breaking ties by using alphabetic order).
# </li><li>
# Display (in a log-log plot) the rank of names vs. number of occurrence for each name.
# </li><li>
# Determine if the plot appears to reflect a power law or not.
# </li><li>
# Answer the key question, about whether the "meme life-cycle" pattern appears to be scale-invariant.
# </li></ul>
# </li></ol>
# </li></ol>
# If you want to use a dataset other than Baby Names, that is fine, just modify the problem accordingly.
#
# Clearly a good result is publishable.

# %% [markdown]
# ##OUR ANSWERS
# 1. Data downloaded (baby data)
# 2. Read articles on memes / names
# 3. Preprocessing done in python
# -filling in missing values using numpy function
#
# -removed names with extremely low variance (a sign the distribution is uniform, power law distributions tend to have high variances when you reach a point, since they exhibit extreme values)
# -there were still some names with missing values, so I removed these from our dataset
#
# - we were left with 1161 names
#
#
# 4. We developed a model based classifying the distribution of the names.  After building models of distributions for various names  we concluded that first names had either **lognormal, exponential, or pareto** distributions.  For goodness of fit we are using the ks.test() function to classify which names have pareto or power law distributions, based on which model gave us the highest p-value.
#
# -The names that have a **pareto distribution are most likely to be representative of the meme-life cycle curve**.  We saw this pattern as unique names such as "Zelda" were placed under the category of pareto distribution or exhibited a power law.  These names are reminiscent of memes, in that they are scale invariant and distributed according to the pareto distribution.  Several other examples of names that we classified as having a meme-like life cycle were "Aloynius", "Adolph", "Rufus", and "Cassius", all names which happenned to have location parameters around the same time a person of that name was famous, or a cultural movement was spreading.  In that sense, these rare, special names act like memes and quickly grow and die out, and unlike names which are log-normally distributed they have no sense of center or mean, as it constantly changes as we change the sample size.  In that sense these names are scale-invariant and exhibit the power law.  **In total we found 506 matches out of our preprocessed sample of 1161 names which exhibited a meme-life cycle**
#
#
# -The names with **exponential distributions we found were names which did not exihibit the meme life-cycle**.  In general names which fell under this category had overall less popularity than log-normally distributed names, and consistently had less births per year than a name in categorized as log-normal.   This makes sense since the exponential distribution by nature has a fatter tail than the lognormal distribution, meaning that it expects to have more smaller values than if it were to be distributed log-normally. This was the smallest category of names, and we classified 206 names as being distributed exponentially.  Some examples we found of exponentially distributed names are "Anthony", "Clifford" and "Calvin", names that are not crazily uncommon like "Zelda" but also names which are not that popular. ** This group was the smallest, and we found only 207 names exhibited an exponential distribution**
#
#
# -The final distribution of names which **did not fit the meme life cycle were names that were distributed log-normally**.  If we make the assumption that there is a set of names which are popular and are somewhat stable, such as "John", "James", and "Michael", we can think of them as a normal random variable. Thus it makes sense to think of their joint distribution as a product of IID normal variables, which makes their joint distribution a log-normal one.  The difference between this and the pareto distribution is that these names do not share the "meme life-cycle" and have the sharp spike in popularity of the names and then a steep decline.  The difference between this and the exponential distribution is that the distribution of the names are more centered around the mean, and we are less likely to see extreme values, either larger or smaller than the mean. **In total 457 names out of our sample of were determined through MLE estimates to be log-normally distributed**
#
# 5. Below you will see a log-log plot of the histogram of a pareto distributed variable which exhibits the power law.  The log-log plot appears to be a line or suggests that the underlying distrbution may exhibit the power law, but is not proof , since at certain scales other distribution can also appear like a line on a log-log plot.  There must be more rigorous tests done to ensure a a model exhibits power law, such as the KS test that we did above.
#
# Our full classification of names is as follows:
# **Names that are distributed exponentially:**
#
# [1]  "Adrienne"   "Aileen"     "Alberta"    "Alfred"
#   [6] "Allan"      "Allen"      "Alton"      "Alvin"      "Andy"
#  [11] "Ann"        "Anne"       "Anthony"    "Antoinette" "Arthur"
#  [16] "Aurora"     "Benito"     "Bennie"     "Bernadette" "Bernard"
#  [21] "Bertha"     "Betsy"      "Boyd"       "Burton"     "Byron"
#  [26] "Calvin"     "Camille"    "Carl"       "Carlton"    "Cecil"
#  [31] "Charlotte"  "Cherry"     "Claire"     "Clarence"   "Claudia"
#  [36] "Clay"       "Clayton"    "Clifford"   "Clifton"    "Clinton"
#  [41] "Clyde"      "Curtis"     "Dallas"     "Daniel"     "Dean"
#  [46] "Dixie"      "Dwight"     "Eddie"      "Edmund"     "Elena"
#  [51] "Elinor"     "Elisabeth"  "Ella"       "Elliott"    "Emanuel"
#  [56] "Emelia"     "Ernest"     "Eunice"     "Eve"        "Evelyn"
#  [61] "Fannie"     "Floyd"      "Frank"      "Frankie"    "Franklin"
#  [66] "Freddie"    "Frederick"  "Fredrick"   "Garland"    "Georgina"
#  [71] "Gilbert"    "Glen"       "Glenna"     "Guadalupe"  "Gwendolyn"
#  [76] "Hans"       "Harlan"     "Harriet"    "Harry"      "Harvey"
#  [81] "Hattie"     "Hezekiah"   "Ida"        "Irene"      "Iris"
#  [86] "Ishmael"    "Ivan"       "Jack"       "James"      "Janette"
#  [91] "Jay"        "Jeanette"   "Jeannette"  "Jerome"     "Joe"
#  [96] "Joel"       "Johnnie"    "Johnny"     "Karl"       "Kathrine"
# [101] "Kenneth"    "Laurence"   "Lawrence"   "Lea"        "Lee"
# [106] "Leland"     "Leon"       "Leonard"    "Leslie"     "Lester"
# [111] "Letitia"    "Lillie"     "Lionel"     "Lloyd"      "Lonnie"
# [116] "Loren"      "Lorene"     "Lorenzo"    "Loretta"    "Lucia"
# [121] "Lula"       "Mae"        "Malcolm"    "Manuel"     "Marcella"
# [126] "Margaret"   "Margarita"  "Marguerite" "Maria"      "Martha"
# [131] "Martina"    "Mary"       "Maryann"    "Mattie"     "Max"
# [136] "Mercedes"   "Milton"     "Mitchel"    "Mona"       "Morris"
# [141] "Myron"      "Neal"       "Ned"        "Neil"       "Nellie"
# [146] "Nick"       "Noel"       "Ollie"      "Paul"       "Pearl"
# [151] "Pedro"      "Pete"       "Peter"      "Philip"     "Pierre"
# [156] "Priscilla"  "Ramon"      "Randolph"   "Ray"        "Reginald"
# [161] "Rex"        "Robbie"     "Robert"     "Roland"     "Rosanna"
# [166] "Rosie"      "Ross"       "Roy"        "Ruben"      "Rudolph"
# [171] "Russell"    "Sammie"     "Santos"     "Sara"       "Shelton"
# [176] "Sherman"    "Sidney"     "Stanley"    "Sterling"   "Stewart"
# [181] "Susanna"    "Sylvia"     "Thaddeus"   "Theresa"    "Therese"
# [186] "Thomas"     "Tomas"      "Tommie"     "Tommy"      "Tony"
# [191] "Vance"      "Vera"       "Verna"      "Vernon"     "Veronica"
# [196] "Victor"     "Vincent"    "Virgil"     "Vivian"     "Wade"
# [201] "Walter"     "Warren"     "Wendell"    "Wesley"     "Wilbert"
# [206] "Willie"     "Winston"
# **Names that show signs of a pareto distribution:**
#
# [1] ""            "Abbie"       "Abby"        "Abe"         "Abigail"
#   [6] "Abram"       "Adam"        "Addie"       "Addison"     "Adelaide"
#  [11] "Adeline"     "Aden"        "Adolph"      "Agatha"      "Agnes"
#  [16] "Aimee"       "Al"          "Albina"      "Alden"       "Alec"
#  [21] "Aline"       "Allison"     "Aloysius"    "Alpha"       "Alphonse"
#  [26] "Alta"        "Alva"        "Alvina"      "Alyce"       "Amalia"
#  [31] "Amanda"      "Amber"       "Ambrose"     "America"     "Amie"
#  [36] "Anastasia"   "Anderson"    "Andre"       "Andres"      "Annabel"
#  [41] "Anson"       "Arlie"       "Armand"      "Art"         "Artie"
#  [46] "Asa"         "Asher"       "Ashley"      "Augusta"     "Augustine"
#  [51] "Augustus"    "Aurelia"     "Austin"      "Ava"         "Avery"
#  [56] "Axel"        "Bailey"      "Barney"      "Bart"        "Basil"
#  [61] "Becky"       "Bella"       "Belle"       "Bennett"     "Bernie"
#  [66] "Bertie"      "Bertram"     "Bettie"      "Beulah"      "Bill"
#  [71] "Birdie"      "Bishop"      "Blanch"      "Blanche"     "Bob"
#  [76] "Brad"        "Bridget"     "Brooks"      "Bruno"       "Bud"
#  [81] "Buford"      "Burl"        "Burt"        "Buster"      "Caleb"
#  [86] "Callie"      "Camilla"     "Carlotta"    "Carolina"    "Carroll"
#  [91] "Carson"      "Cassie"      "Cassius"     "Catharine"   "Cecile"
#  [96] "Celina"      "Charity"     "Charley"     "Chloe"       "Christian"
# [101] "Christina"   "Christopher" "Cinda"       "Clair"       "Clarice"
# [106] "Claud"       "Claudie"     "Claudine"    "Clement"     "Clementine"
# [111] "Cleo"        "Coleman"     "Colin"       "Columbus"    "Corine"
# [116] "Corrie"      "Coy"         "Cruz"        "Cullen"      "Curt"
# [121] "Cyril"       "Cyrus"       "Dan"         "Danial"      "Darius"
# [126] "Dave"        "Davis"       "Dayton"      "Debbie"      "Delmar"
# [131] "Denis"       "Dessie"      "Dewitt"      "Dick"        "Dinah"
# [136] "Dollie"      "Dovie"       "Drew"        "Duke"        "Duncan"
# [141] "Earle"       "Earnest"     "Edythe"      "Effie"       "Elbert"
# [146] "Elda"        "Eleanora"    "Eleanore"    "Eli"         "Elias"
# [151] "Elijah"      "Elisha"      "Ellie"       "Elliot"      "Ellsworth"
# [156] "Elma"        "Elmo"        "Elnora"      "Elsie"       "Elton"
# [161] "Elvin"       "Elwood"      "Emerson"     "Emery"       "Emil"
# [166] "Emile"       "Emilia"      "Emilie"      "Emmitt"      "Emory"
# [171] "Erma"        "Erna"        "Ernestine"   "Ernie"       "Essie"
# [176] "Estelle"     "Etta"        "Eula"        "Evalyn"      "Evan"
# [181] "Evie"        "Ezekiel"     "Ezra"        "Fanny"       "Fay"
# [186] "Felipe"      "Ferdinand"   "Fletcher"    "Flossie"     "Floy"
# [191] "Foster"      "Frederic"    "Freeman"     "Garry"       "Gena"
# [196] "Georgiana"   "Georgianna"  "Georgie"     "Gertie"      "Gertrude"
# [201] "Gideon"      "Gina"        "Goldie"      "Grover"      "Gus"
# [206] "Gussie"      "Hal"         "Hanna"       "Hannah"      "Harmon"
# [211] "Harriett"    "Harriette"   "Harris"      "Harrison"    "Hayes"
# [216] "Henrietta"   "Herschel"    "Hester"      "Hiram"       "Hollie"
# [221] "Hollis"      "Horace"      "Hortense"    "Houston"     "Hubert"
# [226] "Hunter"      "Hyman"       "Idella"      "Ina"         "India"
# [231] "Iola"        "Iona"        "Ione"        "Irwin"       "Isabell"
# [236] "Isabella"    "Isabelle"    "Isadore"     "Isaiah"      "Isiah"
# [241] "Issac"       "Ivory"       "Jackson"     "Jacob"       "Jake"
# [246] "Jarrett"     "Jason"       "Jeff"        "Jeremiah"    "Jessica"
# [251] "Jewel"       "Jewell"      "Johnie"      "Jonah"       "Jonas"
# [256] "Jordan"      "Josh"        "Joshua"      "Josiah"      "Juana"
# [261] "Judd"        "Judson"      "Jules"       "Justin"      "Kate"
# [266] "Katheryn"    "Kizzie"      "Lacy"        "Lavern"      "Lawson"
# [271] "Lela"        "Lenard"      "Leola"       "Leone"       "Leora"
# [276] "Leota"       "Levi"        "Lilian"      "Lilly"       "Lily"
# [281] "Lincoln"     "Lindsay"     "Lindsey"     "Linwood"     "Liza"
# [286] "Lizzie"      "Logan"       "Lois"        "Lon"         "Lottie"
# [291] "Lou"         "Louella"     "Loyd"        "Lucian"      "Lucien"
# [296] "Lucile"      "Lucille"     "Lucinda"     "Luella"      "Luke"
# [301] "Lulu"        "Luna"        "Lura"        "Lyman"       "Mabel"
# [306] "Mable"       "Mac"         "Mack"        "Madge"       "Madison"
# [311] "Magdalene"   "Major"       "Malachi"     "Malcom"      "Malissa"
# [316] "Mamie"       "Mandy"       "Manuela"     "Margarett"   "Margarette"
# [321] "Margery"     "Margret"     "Mariah"      "Marquis"     "Mason"
# [326] "Mathilda"    "Matilda"     "Matthias"    "Maud"        "Maude"
# [331] "Maudie"      "Maxwell"     "May"         "Maybelle"    "Mayme"
# [336] "Mazie"       "Melinda"     "Melissa"     "Melva"       "Merle"
# [341] "Merton"      "Mervin"      "Michel"      "Mildred"     "Milford"
# [346] "Millard"     "Millicent"   "Millie"      "Milo"        "Mina"
# [351] "Monroe"      "Morgan"      "Morton"      "Murray"      "Myrtle"
# [356] "Nannie"      "Nathanial"   "Nell"        "Nena"        "Nettie"
# [361] "Newton"      "Noah"        "Noble"       "Norah"       "Norris"
# [366] "Nova"        "Ocie"        "Octavia"     "Odessa"      "Ola"
# [371] "Olen"        "Olin"        "Olive"       "Oma"         "Omar"
# [376] "Omer"        "Ona"         "Opal"        "Ora"         "Orion"
# [381] "Orpha"       "Orval"       "Orville"     "Otha"        "Otis"
# [386] "Pablo"       "Palmer"      "Pansy"       "Parker"      "Pat"
# [391] "Patsy"       "Pattie"      "Patty"       "Payton"      "Phil"
# [396] "Philomena"   "Phoebe"      "Pierce"      "Porter"      "Presley"
# [401] "Prince"      "Raleigh"     "Reece"       "Reese"       "Reta"
# [406] "Rich"        "Riley"       "Roderick"    "Rolland"     "Romeo"
# [411] "Rosalee"     "Roscoe"      "Roseanna"    "Rosella"     "Rosetta"
# [416] "Roxanna"     "Royal"       "Rufus"       "Russel"      "Ruthie"
# [421] "Sabra"       "Samantha"    "Sanford"     "Santiago"    "Saul"
# [426] "Savannah"    "Schuyler"    "Scott"       "Selena"      "Selina"
# [431] "Selma"       "Serena"      "Seth"        "Seymour"     "Sibyl"
# [436] "Silas"       "Simeon"      "Sol"         "Sophia"      "Sophie"
# [441] "Stanford"    "Sue"         "Sydney"      "Sylvester"   "Tabitha"
# [446] "Taylor"      "Teressa"     "Tessie"      "Thad"        "Thea"
# [451] "Theda"       "Theo"        "Theodora"    "Theron"      "Thurman"
# [456] "Tillie"      "Tim"         "Tina"        "Titus"       "Tobias"
# [461] "Toney"       "Turner"      "Tyler"       "Ulysses"     "Una"
# [466] "Unknown"     "Uriah"       "Vada"        "Velma"       "Vern"
# [471] "Verne"       "Vernie"      "Vesta"       "Vida"        "Viola"
# [476] "Virgie"      "Waldo"       "Walker"      "Wallace"     "Ward"
# [481] "Warner"      "Wes"         "Wilber"      "Wilbur"      "Wilburn"
# [486] "Wilda"       "Wiley"       "Wilford"     "Wilfred"     "Wilhelmina"
# [491] "Willard"     "Wilma"       "Wilmer"      "Wilton"      "Winfred"
# [496] "Winifred"    "Winnie"      "Winnifred"   "Winona"      "Wyatt"
# [501] "Yetta"       "Zack"        "Zelda"       "Zella"       "Zelma"
# [506] "Zoe"         "Zola"
# **Names that are distributed lognormally:**
#
# [1] ""          "Aaron"     "Abel"      "Abraham"   "Ada"       "Adela"
#   [7] "Adele"     "Adrian"    "Albert"    "Alex"      "Alexander" "Alice"
#  [13] "Allie"     "Alma"      "Alonzo"    "Althea"    "Amelia"    "Amos"
#  [19] "Amy"       "Ana"       "Andrew"    "Angela"    "Angelina"  "Angeline"
#  [25] "Angie"     "Anita"     "Anna"      "Annabelle" "Annetta"   "Annette"
#  [31] "Annie"     "Anton"     "Antonia"   "Antonio"   "Archer"    "Archie"
#  [37] "Arnold"    "Aron"      "Aubrey"    "August"    "Avis"      "Barbara"
#  [43] "Beatrice"  "Ben"       "Benjamin"  "Bernice"   "Bert"      "Beryl"
#  [49] "Bessie"    "Betty"     "Beverly"   "Billie"    "Billy"     "Bonnie"
#  [55] "Boston"    "Bradford"  "Bradley"   "Bruce"     "Bryant"    "Carey"
#  [61] "Carlos"    "Carol"     "Caroline"  "Carolyn"   "Carrie"    "Cary"
#  [67] "Catherine" "Cathrine"  "Cecelia"   "Cecilia"   "Celestine" "Celia"
#  [73] "Charles"   "Charlie"   "Chauncey"  "Chester"   "Chris"     "Christine"
#  [79] "Clara"     "Clare"     "Clarissa"  "Clark"     "Claude"    "Cleveland"
#  [85] "Cliff"     "Clint"     "Connie"    "Conrad"    "Constance" "Cora"
#  [91] "Corinne"   "Cornelia"  "Cornelius" "Corrine"   "Cynthia"   "Daisy"
#  [97] "Damon"     "Dana"      "David"     "Deborah"   "Dee"       "Delbert"
# [103] "Delia"     "Delilah"   "Della"     "Delphine"  "Dena"      "Dennis"
# [109] "Dexter"    "Diana"     "Dolly"     "Dolores"   "Don"       "Dona"
# [115] "Donald"    "Donna"     "Donnie"    "Dora"      "Dorcas"    "Doris"
# [121] "Dorothea"  "Dorothy"   "Douglas"   "Dudley"    "Earl"      "Ed"
# [127] "Edgar"     "Edith"     "Edmond"    "Edna"      "Edward"    "Edwin"
# [133] "Elaine"    "Eleanor"   "Elisa"     "Elise"     "Eliza"     "Elizabeth"
# [139] "Ellen"     "Ellis"     "Elmer"     "Eloise"    "Elsa"      "Elva"
# [145] "Elvira"    "Emily"     "Emma"      "Emmett"    "Eric"      "Ervin"
# [151] "Erwin"     "Estella"   "Esther"    "Ethel"     "Eugene"    "Eugenia"
# [157] "Eva"       "Everett"   "Faith"     "Faye"      "Felicia"   "Felix"
# [163] "Fern"      "Fernando"  "Finley"    "Flora"     "Florence"  "Forest"
# [169] "Forrest"   "Frances"   "Francis"   "Francisco" "Fred"      "Freda"
# [175] "Frieda"    "Gabriel"   "Garrett"   "Gary"      "Gene"      "Geneva"
# [181] "Genevieve" "George"    "Georgia"   "Gerald"    "Geraldine" "Gladys"
# [187] "Glenn"     "Gordon"    "Grace"     "Gracie"    "Grant"     "Guy"
# [193] "Hallie"    "Harley"    "Harold"    "Hazel"     "Hector"    "Helen"
# [199] "Helena"    "Helene"    "Henry"     "Herbert"   "Herman"    "Hilda"
# [205] "Homer"     "Hope"      "Howard"    "Hugh"      "Hugo"      "Ila"
# [211] "Imogene"   "Inez"      "Ira"       "Irma"      "Irvin"     "Irving"
# [217] "Isaac"     "Isabel"    "Israel"    "Iva"       "Ivy"       "Jane"
# [223] "Janet"     "Janie"     "Jannie"    "Jasper"    "Jean"      "Jeanne"
# [229] "Jefferson" "Jennie"    "Jenny"     "Jerry"     "Jess"      "Jesse"
# [235] "Jessie"    "Jesus"     "Jim"       "Jimmie"    "Joan"      "Joanna"
# [241] "Jodie"     "Johanna"   "John"      "Jonathan"  "Jose"      "Joseph"
# [247] "Josephine" "Josie"     "Juan"      "Juanita"   "Judith"    "Judy"
# [253] "Julia"     "Julian"    "Julie"     "Juliet"    "Julius"    "June"
# [259] "Justice"   "Justus"    "Katharine" "Katherine" "Kathleen"  "Kathryn"
# [265] "Katie"     "Katy"      "Kelly"     "King"      "Kirk"      "Kitty"
# [271] "Larry"     "Laura"     "Lauretta"  "Layton"    "Leah"      "Leanna"
# [277] "Leila"     "Lelia"     "Lena"      "Lenora"    "Lenore"    "Leo"
# [283] "Leona"     "Leonidas"  "Leroy"     "Lessie"    "Leta"      "Letha"
# [289] "Lewis"     "Lila"      "Lillian"   "Lina"      "Linda"     "Lola"
# [295] "Lora"      "Lorena"    "Louie"     "Louis"     "Louise"    "Lucretia"
# [301] "Lucy"      "Luis"      "Luther"    "Lydia"     "Lyle"      "Lynn"
# [307] "Madeline"  "Magdalena" "Maggie"    "Mai"       "Malinda"   "Marcia"
# [313] "Marcus"    "Margie"    "Marian"    "Marie"     "Marietta"  "Marion"
# [319] "Marjorie"  "Mark"      "Marshall"  "Martin"    "Marvin"    "Mathew"
# [325] "Mathias"   "Matt"      "Matthew"   "Maurice"   "Maynard"   "Melvin"
# [331] "Merrill"   "Michael"   "Micheal"   "Miguel"    "Mike"      "Miles"
# [337] "Minerva"   "Minnie"    "Miriam"    "Mitchell"  "Mollie"    "Molly"
# [343] "Monica"    "Moses"     "Muriel"    "Myra"      "Nan"       "Nancy"
# [349] "Naomi"     "Natalie"   "Nathan"    "Nathaniel" "Nelson"    "Neva"
# [355] "Nicholas"  "Nina"      "Nola"      "Nona"      "Nora"      "Norma"
# [361] "Norman"    "Olga"      "Oliver"    "Olivia"    "Ophelia"   "Orlando"
# [367] "Oscar"     "Otto"      "Owen"      "Patience"  "Patrick"   "Paula"
# [373] "Paulina"   "Pauline"   "Pearlie"   "Peggy"     "Penelope"  "Percy"
# [379] "Perry"     "Phillip"   "Phyllis"   "Polly"     "Preston"   "Queen"
# [385] "Quincy"    "Rachael"   "Rachel"    "Rae"       "Rafael"    "Ralph"
# [391] "Randall"   "Raymond"   "Reba"      "Rebecca"   "Regina"    "Rena"
# [397] "Rene"      "Reuben"    "Rhoda"     "Richard"   "Rita"      "Roberta"
# [403] "Rodney"    "Roger"     "Rosa"      "Rosalie"   "Rose"      "Rowena"
# [409] "Roxie"     "Ruby"      "Ruth"      "Sadie"     "Sallie"    "Sally"
# [415] "Sam"       "Samuel"    "Sandy"     "Sarah"     "Shelby"    "Shirley"
# [421] "Simon"     "Solomon"   "Spencer"   "Stacy"     "Stella"    "Stephen"
# [427] "Steve"     "Steven"    "Stuart"    "Susan"     "Susie"     "Suzanne"
# [433] "Ted"       "Tena"      "Teresa"    "Terry"     "Thelma"    "Theodore"
# [439] "Timothy"   "Tom"       "Tracy"     "Travis"    "Tressa"    "Troy"
# [445] "Truman"    "Van"       "Victoria"  "Violet"    "Virginia"  "Wanda"
# [451] "Wayne"     "Will"      "Willa"     "William"   "Willis"    "Wilson"
# [457] "Zena"

# %% [markdown]
# # Getting the "Baby Memes" Data

# %%
import re
import glob
import pandas as pd
import numpy as np

# Assemble all of the data into a single DataFrame
years = range(1880, 2011)
pieces = []
columns = ['name', 'sex', 'births']

yob_filename_re = re.compile(r"yob(\d{4})")

yobs = glob.glob("names/yob*.txt")

for path in yobs:
    year = yob_filename_re.findall(path)[0]
    frame = pd.read_csv(path, names=columns)
    frame['year'] = int(year)
    pieces.append(frame)

# Concatenate everything into a single DataFrame
names = pd.concat(pieces, ignore_index=True)

# %%
def add_prop(group):
    births = group.births.astype(float)
    group['prop'] = births / births.sum()
    return group
names = names.groupby(['year', 'sex']).apply(add_prop)
names.head()
# Out:
#         name sex  births  year      prop
# 0       Mary   F    7065  1880  0.077643
# 1       Anna   F    2604  1880  0.028618
# 2       Emma   F    2003  1880  0.022013
# 3  Elizabeth   F    1939  1880  0.021309
# 4     Minnie   F    1746  1880  0.019188
#
# [5 rows x 5 columns]

# %%
np.allclose(names.groupby(['year', 'sex']).prop.sum(), 1)
# Out:
# True

# %%
def get_top(group): # currently only samples 10 top names
    return group.sort_index(by='births', ascending=False)[:1000]

# %%
grouped = names.groupby(['year', 'sex'])
top1000 = grouped.apply(get_top) # per year and gender top 1000

# %%
boys = top1000[top1000.sex == 'M']
girls = top1000[top1000.sex == 'F']

# %%
total_births = top1000.pivot_table('births', rows='year', cols='name', aggfunc=sum)
total_births=total_births.fillna(method='pad') # try padding NA values
total_births=total_births.dropna(axis=1) # remove columns (names that still have NA values)
print total_births.head() #get it down to 943 names
# Out:
# name  Aaron  Abbie  Abby  Abe  Abel  Abigail  Abner  Abraham  Abram  Ada  \
# year
# 1880    102     71     6   50     9       12     27       81     21  652
# 1881     94     81     7   36    12        8     30       86     30  628
# 1882     85     80    11   50    10       14     32       91     25  689
# 1883    105     79    11   43    12       11     27       52     20  778
# 1884     97     98     6   45    14       13     33       67     29  854
#
# name  Adah  Adaline  Adam  Adda  Addie  Addison  Adela  Adelaide  Adelbert  \
# year
# 1880    24       23   104    14    282       19      9        65        28
# 1881    29       18   116    20    294       17      7        62        14
# 1882    27       16   114    17    347       21     17        74        14
# 1883    41       11   107    24    369       20     15        85        14
# 1884    33       20    83    18    364       17     11        98        17
#
# name  Adele
# year
# 1880     41 ...
# 1881     43 ...
# ...

# %%
total_births_boys = boys.pivot_table('births', rows='year', cols='name', aggfunc=sum) # seperated by sex 
# in case we wish to model just names that are solely male
total_births_boys=total_births_boys.fillna(method='pad') # try padding NA values
total_births_boys=total_births_boys.dropna(axis=1) # remove columns (names that still have NA values)
# get it down to 1000 names
print total_births_boys.head()
# Out:
# name  Aaron  Abe  Abel  Abner  Abraham  Abram  Adam  Addie  Addison  Adelbert  \
# year
# 1880    102   50     9     27       81     21   104      8       19        28
# 1881     94   36    12     30       86     30   116      7       17        14
# 1882     85   50    10     32       91     25   114      6       21        14
# 1883    105   43    12     27       52     20   107      7       20        14
# 1884     97   45    14     33       67     29    83      8       17        17
#
# name  Aden  Adolf  Adolph  Adolphus  Adrian  Al  Albert  Albin  Albion  \
# year
# 1880     7      6      93        17      18  12    1493      6       6
# 1881     7      6      90        21      12  19    1319      5       7
# 1882     7      6      94        14      18  33    1499     11       7
# 1883     7      6     115        19      14  21    1496      7       7
# 1884     7      6     107        17       9  18    1435     13       7
#
# name  Alcide
# year
# 1880       7 ...
# ...

# %%
total_births_girls = girls.pivot_table('births', rows='year', cols='name', aggfunc=sum)
# in case we wish to model just names that belong only to females.  Prof mentioned predator/prey
# relationships between names, so one possible model is that names follow this pattern, in terms of
# the ratio of male to female names, so I extracted the total_births for girls in case we needed it later.
total_births_girls=total_births_girls.fillna(method='pad') # try padding NA values
total_births_girls=total_births_girls.dropna(axis=1) # remove columns (names that still have NA values)
#get it down to 943 names
print total_births_girls.head()
# Out:
# name  Abbie  Abby  Abigail  Ada  Adah  Adaline  Adda  Addie  Adela  Adelaide  \
# year
# 1880     71     6       12  652    24       23    14    274      9        65
# 1881     81     7        8  628    29       18    20    287      7        62
# 1882     80    11       14  689    27       16    17    341     17        74
# 1883     79    11       11  778    41       11    24    362     15        85
# 1884     98     6       13  854    33       20    18    356     11        98
#
# name  Adele  Adelia  Adeline  Adella  Adelle  Adina  Adline  Adrienne  Agatha  \
# year
# 1880     41      18       54      26       5      5       8         5      16
# 1881     43      21       58      16       5      5       8         5      10
# 1882     64      23       70      18       5      5       8         5      21
# 1883     68      30       82      16       5      5       8         5      14
# 1884     71      37      112      16       5      5       9         5      18
#
# name  Agnes
# year
# ...

# %%
subset = total_births[['Carolyn', 'Chloe', 'Laura', 'Michael', 'James', 'John', 'Mary', 'Amanda']]
# some sample plots to show distribution of names, to show plots run ipython notebook --pylab
# Distributions look similar overall, but in particular traditional names in particular Michael, James, John
# and Mary have very similar distributions. Based on intuition, because these names are traditional
# and not fads (like memes) we do not expect them to exhibit the meme lifecycle, but rather to be distribute
# log-normally, since they are a product of IID random variables

subset.plot(subplots=True, figsize=(12,10), grid=False, title="Number of births per year")
# Out:
# array([<matplotlib.axes.AxesSubplot object at 0x116fbb590>,
# ...
#        <matplotlib.axes.AxesSubplot object at 0x11358fad0>], dtype=object)

# %%
# %%R -w 900 -h 900 -i total_births #import our total_birth object from python
# # contains 1835 total names, histories of 1000 male names and 835 female birth names, these names have no missing values
# # and were at some point in the top 1000 ranking of names.
# library(plyr)
# library(ggplot2)
# str(total_births)
# Out:
# 'data.frame':	133 obs. of  1835 variables:
#  $ Aaron      : num [1:133(1d)] 102 94 85 105 97 88 86 78 90 85 ...
#   ..- attr(*, "dimnames")=List of 1
#   .. ..$ x: chr  "1880" "1881" "1882" "1883" ...
#  $ Abbie      : num [1:133(1d)] 71 81 80 79 98 88 84 104 137 107 ...
#   ..- attr(*, "dimnames")=List of 1
#   .. ..$ x: chr  "1880" "1881" "1882" "1883" ...
#  $ Abby       : num [1:133(1d)] 6 7 11 11 6 6 7 7 9 9 ...
#   ..- attr(*, "dimnames")=List of 1
#   .. ..$ x: chr  "1880" "1881" "1882" "1883" ...
#  $ Abe        : num [1:133(1d)] 50 36 50 43 45 47 50 37 46 39 ...
#   ..- attr(*, "dimnames")=List of 1
#   .. ..$ x: chr  "1880" "1881" "1882" "1883" ...
#  $ Abel       : num [1:133(1d)] 9 12 10 12 14 6 16 11 8 9 ...
#   ..- attr(*, "dimnames")=List of 1
#   .. ..$ x: chr  "1880" "1881" "1882" "1883" ...
#  $ Abigail    : num [1:133(1d)] 12 8 14 11 13 9 15 13 18 20 ...
#   ..- attr(*, "dimnames")=List of 1
#   .. ..$ x: chr  "1880" "1881" "1882" "1883" ...
# ...

# %% [markdown]
# ##Names = "Memes" ?
#
# This kind of curve also has turned up in analysis of news on the internet:
# <blockquote>
#    <i>Meme Tracking and the Dynamics of the News Cycle</i>,
#    Jure Leskovec, Lars Nystrom, Jon Kleinberg.
#    KDD 2009.<br/>
#    http://www.cs.cornell.edu/home/kleinber/kdd09-quotes.pdf‎
#    (<a href="http://cyber.law.harvard.edu/sites/cyber.law.harvard.edu/files/memetracker-harvard-feb10.pdf">slides</a>)
# </blockquote>
# The curve above is visible in Figures 4 and 5 in this paper,
# where it is typical of the number of online news articles (and blog articles after this)
# that contain a certain memorable phrase ("meme") that gets repeated rapidly when it appears.
#
# The paper tries to formalize the shape of the curve, but it doesn't finish the job -- it offers some equations, but no validation or justification.
#
# The idea is compelling, though -- this kind of curve seems to describe the growth and decline of a population of instances of some Meme -- a phrase or sign that has meaning within a culture, and "spreads" by communication within the culture (http://en.wikipedia.org/wiki/Meme).
#
# In other words, the life-cycle of baby names seems to look similar to the life-cycle of memes in news articles.
# This makes sense if names are viewed as memes.

# %%
# %%R
#
# library(MASS)
# library(nortest)
# library(evir)
# library(evd)

# %%
# %%R
# # running our comparision tester on some sample names which we plotted earlier to make sure it works
# Caroline <- total_births$Caroline
# Carolyn <- total_births$Carolyn
# Aaron <- total_births$Aaron
# Chloe <- total_births$Chloe
# Laura <- total_births$Laura
# Michael <- total_births$Michael # The p values for the log-normal ks-test were very low for the names
# John <-total_births$John # Michael, John, Mary, and James(all < 1%), suggesting that it also is a good model
# Mary <-total_births$Mary # for modeling names.
# James <- total_births$James

# %%
# %%R
#
# names = names(total_births)
# p = dim(total_births)[2]
# i=1;
# exponential=c();
# pareto=c();
# lognormal=c();
# for (person in total_births)
# {
#     if (var(person)>1000) # we only include names with high variance, or else the ks test fails on them
#         {
#             print(names[i])
#             best_model = fit_comparisions1(person) #function defined earlier that returns model with highest p-value using ks test
#             if (best_model==2)
#                 exponential[length(exponential)+1] <- names[i]
#             else if (best_model==3)
#                 pareto[length(pareto)+1] <- names[i]
#             else if (best_model==1)
#                 lognormal[length(lognormal)+1] <- names[i]
#         }
#     i=i+1
#
# }
# cat("Names that are distributed exponentially:");print(exponential)
# cat("Names that show signs of pareto distribution:");print(pareto)
# cat("Names that are distributed lognormally:");print(lognormal)
# Out:
# [1] "Aaron"
# [1] 0.001481975
# lognormal has the highest ks test p-value: [1] 0.001481975
# [1] "Abbie"
# [1] 0.02523774
# pareto has the highest ks test p-value: [1] 0.02523774
# [1] "Abby"
# [1] 1.343161e-06
# pareto has the highest ks test p-value: [1] 1.343161e-06
# [1] "Abe"
# [1] 0.1364672
# pareto has the highest ks test p-value: [1] 0.1364672
# [1] "Abel"
# [1] 0.01133008
# lognormal has the highest ks test p-value: [1] 0.01133008
# [1] "Abigail"
# [1] 0.1075191
# pareto has the highest ks test p-value: [1] 0.1075191
# [1] "Abraham"
# [1] 0.3065337
# lognormal has the highest ks test p-value: [1] 0.3065337
# [1] "Abram"
# [1] 0.001393582
# pareto has the highest ks test p-value: [1] 0.001393582
# [1] "Ada"
# [1] 0.02329694
# lognormal has the highest ks test p-value: [1] 0.02329694
# [1] "Adam"
# [1] 0.02575261
# pareto has the highest ks test p-value: [1] 0.02575261
# [1] "Addie"
# [1] 4.471297e-05
# pareto has the highest ks test p-value: [1] 4.471297e-05
# [1] "Addison"
# ...

# %%
# %%R
# #loglogplot should be linear if the distribution follows a power law (but not vice versa)
# #looking at the plot, from the years 1980-2000 Chloe's loglogplot roughly follows a line suggesting that
# # along with the ks test that chloe's name might follow a power law or pareto distribution
# Zelda <-total_births$Zelda
# Mary <-total_births$Mary
# Allan <-total_births$Allan
#
# hist(log(Zelda),log="y",breaks=7,freq=F) #pareto
# hist(Zelda,freq=F)
#
# hist(log(Mary),log="y",breaks=9,freq=F) #lognormal
# hist(Mary,freq=F)
#
# hist(Allan,freq=F)#exponential
# hist(log(Allan),log="y",breaks=9,freq=F)
